# %% [markdown]
# # Baseball Case Study
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
import scipy as stats
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
# Reading the csv file from dataset
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# The dataset contains 16 features which contains the statistics summary of the baseball players and other one is our target variable. In this dataset 'W' is the target variable, which contains the number of predicted wins. Also we can see that the dataset contains only numerical values. and no categorical data. So by observing the dataset and problem statement it's a Regression type problem.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Column Description
# 1)R --> Runs
# 2)AB --> At Bats
# 3)H --> Hits
# 4)2B --> Doubles
# 5)3B --> Triples
# 6)HR --> Homeruns 7)BB --> Walks 8)SO --> Strikeouts 9)SB --> Stolen Bases 10)RA --> Runs Allowed 11)ER --> Earned Runs 12)ERA --> Earned Run Average (ERA) 13)CG --> Complete Game 14)SHO --> Shutouts 15)SV --> Saves 16)E --> Errors 17)W --> Wins
# Problem Type
# 1) Given the number of inputs the Machine learning Algorithm has to predict the number of wins (W)
#
# 2) Target Variable is WINS

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Checking the dimension of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30 rows and 17 columns including the target variable.

# %%
# Checking the types of the dataset
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All the columns have integer data type except the column ERA(Earned Run Average) which is of float data type.
# Since all the columns are numerical in nature and there are no categorical data, so no need to encode the data.

# %%
# To get good overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# From this we can get the good overview of the dataset which includes indexing type, column type, no-null values, data types and memory usage.

# %%
# Checking the number of unique values in each column
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# It gives number of unique values that each column hold.

# %%
# Checking the null values in the dataframe
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# # There are no missing values in the dataset. Let'e visualize this by heat map.

# %%
# Let's visualize the null values clearly
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# So it's clear that no missing values present, so we can proceed further.

# %%
# Checking how many columns are there in the dataset
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the columns present in the dataset.

# %%
# Checking the uniqueness of target variable.
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the unique values present in the target variable'W'.

# %%
# List of values in the target variable
df["W"].value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# This gives the list of values in the target variable which has int64 data type.

# %%
# Checking wheather the dataset contains any space
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# It seems that there are no spaces in the dataset.

# %% [markdown]
# # Description of Dataset

# %%
# Statistical summary of dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the statistical information of the dataset. The summary of this dataset looks perfect since there is no negative/ invalid values present.
#
# From the above description we can observe the following things.
#
# The counts of all the columns are same, this means there are no null values present in any of the columns.
#
# In the target column we can observe the mean is bit less than median(50%), so it is skewed to the left. Since the mean is 80.96 and maximum is 100, it means that the team won more matches.
#
# In the column R(Runs) also median is more than the mean then it is skewed to left. these differences can also be seen in the columns 2B, BB, SO, RA, ER, ERA and SHO. These columns are skewed to left.
#
# The mean is more than median in the columns AB, H, HR, SV and E which means they are skewed to right.
#
# Also the mean and the meadian are same in the columns 3B and SB which means the data is normal or symmetrical. Also the feature CG has mean bit higher than the meadian so its almost normal.
#
# There is a huge differences in max and 75% percentile(3rd quantile).
#
# So from these observations we can conclude that the ourliers present in many of these columns. We will remove these outliers using some methods later.

# %%
# Visualizing the statistics of the columns using Heatmap
plt.figure(figsize=(16,9))
sns.heatmap(df.describe(),linewidths=0.1,fmt='0.1f',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate analysis

# %%
# Histogram for target variable
sns.histplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# Fromt this histogram plot, we can infer that the data is normally distributed and there is no presence of skewness. The minimum wins of the team rate is 63 and maximum is 100 also mean of wins of the team rate is 80. The wins os the team is more between 75 to 80 and it is low in the range 70 to 75.

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distplots we can observe that most of the columns are normally distributed and some of them have skewness too.
#
# From the distplot we can observe the following
#
# The target column 'W'(wins) looks normally distributed and also we can observe there is no skewness.
#
# So from the graph it is clear that the winning rate is between 63 to 100 and mean of W is 80.
#
# The data in the feature 'R'(Runs) is not normal and the median is more than the mean so it is skewed to left.
#
# The run rate lies between 570-890. These differences can also be seen in the columns 'BB'(Walks), 'SO'(strike outs), 'RA'(Runs allowed), 'ERA'(Earned run average), 'SHO'(Shutouts). Eventhough they looks normal but has skewness.
# The data in the feature 'AB'(At Bats) looks normally distributed and has no skewness.
# The value of AB mostly lies between 5300-5650.
#
# The data in the features 'H'(Hits), 'HR'(homeruns),'SV'(saves) and 'E'(errors) are not normal and the mean is more than the median which means skewed to right.
# '2B'(doubles) also looks normal and bit skewness present since the median is bit more than mean.
# The doubles rate is between 230-300.
#
# The mean and the meadian is almost same in the feature columns '3B'(tribles) and 'SB'(Stolen Bases) the data is normally distributed and there is no skewness. Also the column 'CG'(complete games) is looks almost normal and has no skewness
# The column 'ER'(Earned Runs) is normal and has no skewness.

# %% [markdown]
# # checking for outliers

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# By observing the boxplots we can observe the outliers are present in the columns 'R', 'ERA', 'SHO', 'SV', and 'E'. We will remove these outliers using either Zscore or IQR method beforr building our machine learning models.

# %% [markdown]
# # Bivariate Analysis

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Errors')
sns.scatterplot(df['R'],df['E'],hue=df["W"]);
plt.xlabel("Runs")
plt.ylabel("Errors")
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# This scatter plot gives the relation between the Runs and the Errors on the basis of Wins. There is no linear relationship between these columns. We can infer that there is no correlation. The runs between 650-730 with the error upto 95 has more wins. Also we can see the presence of outliers.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Hits')
sns.scatterplot(df['R'],df['H'],hue=df["W"],palette="husl");
plt.xlabel("Runs")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# As we can infer that the there is no linearity between the columns. Also the rate of runs is high in the range 650 to 750 with the rate of hits renges 1500, which means the wins of the team is more in these ranges.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between AB and Hits')
sns.scatterplot(df['AB'],df['H'],hue=df['W']);
plt.xlabel("At Bats")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# There is a weak linear relationship between the features. As the At Bats rates increases with the rate of Hits then the Wins of teams also increases.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between RA AND ERA')
sns.scatterplot(df['RA'],df['ERA'],hue=df['W'],palette="husl");
plt.xlabel("Runs Allowed")
plt.ylabel("Earned Run Average")
# Out:
# Text(0, 0.5, 'Earned Run Average')

# %% [markdown]
# Here we can see the strong linear relationship between the columns. As the Runs allowed increases ERA also increases which means the winning rate also increases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Wins ')
sns.lineplot(df['R'],df['W'], color='r') 
plt.xlabel("Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# We can observe that the Runs rate is high in the range 640-650 followed by the range 700, so in this range the wins of team is also high. As the run rate increases the rate of wins also increases.

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Walks and Wins ')
sns.lineplot(df['BB'],df['W'], color='darkorange') 
plt.xlabel("Walks")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here also the winning rate of the team increases as the number of Walks increases.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Doubles and Wins')
sns.lineplot(df['2B'],df['W'],color="green");
plt.xlabel("Doubles")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The doubles also have good relationship with the target. When there is high number of doubles then there is high chances of winning.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Stolen Bases and Wins')
sns.lineplot(df['SB'],df['W'],color="blue");
plt.xlabel("Stolen Bases")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# There is no linear relationship exists between these columns. The winning rate is high in the range 95-100 SB.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs Allowed and Wins')
sns.scatterplot(df['RA'],df['W']);
plt.xlabel("Runs Allowed")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The target column has negative linear relationship with the feature Runs Allowed, since the data is falling from left to right which means label is highly correlated with the feature.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs and Wins')
sns.scatterplot(df['ER'],df['W']);
plt.xlabel("Earned Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here also the data falling from left to right which means there is inverse linear relationship between the label and the target. As the ER decreases, the winning rate also decreases.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs Average and Wins')
sns.scatterplot(df['ERA'],df['W']);
plt.xlabel("Earned Runs Average")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# As the ERA decreases Wins rate also decreases, which means negative linear relatioship and target is highly correlated with the feature.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs and Earned Runs Average')
sns.scatterplot(df['ER'],df['ERA'],hue=df["W"],palette="husl");
plt.xlabel("Earned Runs")
plt.ylabel("Earned Runs Average")
# Out:
# Text(0, 0.5, 'Earned Runs Average')

# %% [markdown]
#  There is a strong linear relationship between the features. As the Earned Runs increases, Earned Runs Average also increases. The winning rate is high in the range 540-650.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Saves and Wins')
sns.regplot(df['SV'],df['W'],color="darkorange");
plt.xlabel("Saves")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# We can infer that there is a positive linear relationship between the feature Saves and the wINS. As the Saves increases the wins of the team also increases.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between ShutOuts and Wins')
sns.regplot(df['SHO'],df['W'],color="darkorange");
plt.xlabel("ShutOuts")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# There is no much linearity between the feature and the label. In some of the data wecan see whenever the shoutouts is high then there is a chance of win.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Complete Games and Wins')
sns.regplot(df['CG'],df['W'],color="darkorange");
plt.xlabel("Complete Games")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Here also the data is scattered and has no much linear relationship between the feature and the label.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Triples and Wins')
sns.regplot(df['3B'],df['W'],color="r");
plt.xlabel("Triples")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# There is a negative linear relationship between the feature 3B and the label Wins.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Error and Wins')
sns.regplot(df['E'],df['W'],color="r");
plt.xlabel("Error")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The data is scattered and there is no linear raltionship between the two columns. As we can see the Error level is high in hte range 86-95(say).

# %% [markdown]
# # Multivariate Analysis

# %%
# Checking the pairwise relation in the dataset.
sns.pairplot(df,hue="W",palette="husl")

# %% [markdown]
# This pair plot gives the pairwise relation between the columns which is plotted on the basis of target variable "W". Here we can observe the relation between the features and label.
#
# From this pairplot we can observe that the existence of correlation between two variables and on the diagonal we can see distribution plotting.
#
# We can infer the linear relationship between the features RA and ERA, RA and ER and ER and ERA.
#
# Also the correlation exists between the features and there outliers present in some columns let's remove them.
#
# We have already been identified the outliers using bixplot. We have outliers in the columns 'R', 'ERA', 'SHO', 'SV', and 'E' in which we need to remove the outliers. Let's remove them by using Zscore method.

# %% [markdown]
# # Removing outliers

# %% [markdown]
# # 1.Zscore method

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Features containing outliers
features = df[["R","ERA","SHO","SV","E"]]

# %%
# Using zscore to remove outliers
from scipy.stats import zscore

z=np.abs(zscore(features))

z
# Out:
# array([[0.61907797, 0.50695519, 0.81462859, 1.67160651, 0.46146963],
#        [0.13443166, 0.25459752, 0.1728    , 0.24987932, 0.60719689],
#        [0.33290586, 0.64134684, 0.32091429, 0.65485616, 1.11724227],
#        [1.14641931, 0.05301004, 0.56777144, 0.78410408, 0.48575751],
#        [0.01327008, 1.53131824, 0.1728    , 1.04259994, 0.60719689],
#        [3.50964704, 0.35016492, 0.32091429, 1.17184786, 0.46146963],
#        [1.31142984, 0.16500309, 1.80205719, 0.6376231 , 0.0971515 ],
#        [0.4286812 , 0.20980031, 0.32091429, 0.00861653, 1.26296953],
#        [0.76562578, 0.48455658, 0.1728    , 2.18859821, 0.04857575],
#        [1.03448909, 0.79216414, 0.32091429, 0.39636031, 0.194303  ],
#        [1.08641548, 0.63537388, 0.56777144, 0.24987932, 1.79730279],
#        [0.70562195, 0.86533293, 0.41965715, 0.52560823, 0.68006051],
#        [0.47137623, 0.03658439, 0.1728    , 0.37912725, 0.0971515 ],
#        [0.55792022, 0.45618501, 0.1728    , 0.24987932, 0.02428788],
# ...

# %% [markdown]
# Now we have removed the outliers.

# %%
# Creating new dataframe
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# This is the new dataframe after removing the outliers.

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The old dataset contains 30 rows and 17 columns.

# %%
new_df.shape
# Out:
# (29, 17)

# %% [markdown]
# The new dataset contains 29 rows and 17 columns. Its looks like there is no more data loss. Let's check the dataloss.

# %%
# Checking the the data loss
data_loss = (30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# The Data loss percentage is 3.33% which is less.

# %% [markdown]
# # 2. IQR (Inter Quantile Range) method

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df1=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (20, 17)

# %% [markdown]
# The new dataframe using IQR method has 20 rows and 17 columns.

# %%
# Let's check the dataloss
data_loss = (30-20)/30*100
data_loss
# Out:
# 33.33333333333333

# %% [markdown]
# The data loss is 33.33% which is too high,so we cant use this method for removing outliers.
# I am considering Z score method for outliers removal as data loss is minimal.

# %% [markdown]
# # Checking the skewness

# %%
# Checking the skewness
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# The skewness present in the columns "H", "CG", "SHO", "SV" and "E". Will remove this now.

# %% [markdown]
# The skewness present in the  following columns as the skewness value is more than 0.5
# "H", "CG", "SHO", "SV" and "E".

# %% [markdown]
# # Removal of  Skewness using yeo-johnson method

# %%
skewed_cols = ["CG", "SHO", "SV", "E"]

# %%
# Using yeo-johnson method to remove the skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
new_df[skewed_cols] = scaler.fit_transform(new_df[skewed_cols].values)
new_df[skewed_cols].head()
# Out:
#          CG       SHO        SV         E
# 0 -0.307098 -0.787002  1.532753 -0.348265
# 1 -0.307098  0.236737  0.312020 -0.540820
# 2  2.011315 -0.252844 -0.664137 -1.326125
# 3  1.264463 -0.513555 -0.820689  0.650818
# 4  1.264463  0.236737 -1.149165 -0.540820

# %%
new_df['H'] = np.log(new_df['H'])

# %%
# Now let's check the skewness after using the transformation
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# Now the skewness has been removed. Let's visualize it.
#
# I have used all the methods to remove the skewness in the column"H" but the skewness is not reducing in this column.
# It is because the feature "H" might have some relation with the target. We will remove this column if required in upcoming steps.

# %%
# After removing let's check how the data has been distributed in each column.

features_skewed = ["H","CG", "SHO", "SV", "E"]
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in new_df[features_skewed]:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(new_df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# We can see the data is normally distributed and skewness is also removed.
# But the column "H" still has skewness.
# First will check the correlation with the target, if there is necessary will drop this column.

# %% [markdown]
# # Correlation between the target variable and independent variables

# %%
# Checking the correlation between features and the target
cor = new_df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.020787  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432235  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.770155  0.490752  0.445604 -0.064653
# H   -0.020787  0.432235  0.770155  1.000000  0.527354  0.579733 -0.219201
# 2B   0.384886  0.469293  0.490752  0.527354  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.579733  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219201 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221773  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.373302 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.420201  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243639 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.279955 -0.224993  0.333731 -0.062094
# ...

# %% [markdown]
# This gives the correlation between the denpendent and independent variables. We can visualize this by plotting heat map.

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(16,9))
sns.heatmap(new_df.corr(),linewidths=.1,fmt='0.2f', cmap="Blues_r", annot = True)
plt.yticks(rotation=0);

# %% [markdown]
# This heat map contains both positive and negative correlation.
#
# Positvely corelated columns:
#     1. R
#     2. AB
#     3. 2B
#     4. 3B
#     5. SO
#     6. SB
#     7. RA
#     8. ER
#     9. ERA
#
# Negatively corelated columns:
#     1.W
#     2.H
#     3.HR
#     4.BB
#     5CG
#     6.SHO
#     7.SV

# %% [markdown]
# The column "H" and "CG" has no correlation with the label, we can drop these columns.
#
# Apart from this label and feature relation we can also infer that the features "ERA", "ER" and "RA" are highly positively correlated with each other. Which causes multicollinearity problem, to avoid this problem will check VIF value and will drop the columns if necessary.

# %%
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.756713
# SHO    0.481626
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# CG     0.007696
# H     -0.020787
# E     -0.079633
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(22,7))
new_df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between lanel and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# Now we can easily analyse the data, here the feature "H" and "CG" has very less correaltion with the label. Let's drop them.

# %%
new_df.drop("H", axis=1, inplace=True)

# %%
new_df.drop("CG", axis=1, inplace=True)

# %%
new_df.head()
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# Dataframe after removing irrelevent columns

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Separating the independent and target variables into x and y

# %%
x = new_df.drop("W", axis=1)
y = new_df["W"]

# %%
x.shape
# Out:
# (29, 14)

# %% [markdown]
# It provides the size of independent variables

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# It provides the size of target variable.

# %%
x.head()
# Out:
#      R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# Dataset containg all independent variables.

# %% [markdown]
# # Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# ...

# %% [markdown]
# # Checking VIF values to solve multicollinearity

# %%
# Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#      VIF values Features
# 0      6.219825        R
# 1      9.828077       AB
# 2      2.683572       2B
# 3      3.196853       3B
# 4      7.369072       HR
# 5      2.686472       BB
# 6      2.741072       SO
# 7      1.757901       SB
# 8    179.096825       RA
# 9   1754.643859       ER
# 10  1310.260128      ERA
# 11     3.086344      SHO
# 12     4.021573       SV
# 13     1.742105        E

# %% [markdown]
# The VIF value is more than 10 in the columns "AB", "RA", "ER", "ERA". Let's drop these one by one. First drop the colummn having highest VIF value that is "ER".

# %%
x.drop("ER", axis=1, inplace=True)

# %%
# Againing checking the VIF after removing one column
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values Features
# 0     4.352902        R
# 1     3.177214       AB
# 2     2.597985       2B
# 3     3.072775       3B
# 4     4.949255       HR
# 5     2.561982       BB
# 6     2.661842       SO
# 7     1.680467       SB
# 8   119.939744       RA
# 9   111.859162      ERA
# 10    2.932319      SHO
# 11    2.112465       SV
# 12    1.742101        E

# %% [markdown]
# Now we can see the multicollinearity still exists, so let me drop the column "RA".

# %%
x.drop("RA", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values Features
# 0     4.250076        R
# 1     2.238746       AB
# 2     2.597917       2B
# 3     3.030073       3B
# 4     4.562014       HR
# 5     2.222720       BB
# 6     2.042786       SO
# 7     1.568151       SB
# 8     3.878177      ERA
# 9     2.651314      SHO
# 10    1.954370       SV
# 11    1.493128        E

# %% [markdown]
# Now we can observe all the values are less than 10 which means we have solved the multicollinearity problem.
# let's move further to model building.

# %%
# Dataset after preprocessing 
x.head()
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0  0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1  0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2 -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3 -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4  0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
#
#          SB       ERA       SHO        SV         E
# 0  0.905953 -0.511388 -0.787002  1.532753 -0.348265
# 1 -0.585315  0.238952  0.236737  0.312020 -0.540820
# 2  0.116458 -0.643801 -0.252844 -0.664137 -1.326125
# 3 -0.673037  0.040333 -0.513555 -0.820689  0.650818
# 4 -0.015124  1.496876  0.236737 -1.149165 -0.540820

# %% [markdown]
# # Modeling

# %% [markdown]
# # Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9291790579976077  on Random_state  50

# %% [markdown]
# Maximum r2 score is 92% at random state: 50

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# creating new test train split

# %% [markdown]
# # Applying Regression Algorithms

# %% [markdown]
# # 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# Checking r2score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

# prediction
predLR=LR.predict(x_test)
print('R2_score:',r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predLR))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predLR))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 0.9291790579976077
# MAE: 2.4627865987898443
# MSE: 10.163242343651952
# RMSE: 3.187984056367276

# %% [markdown]
# The R2 score for linear regression is 92.91%

# %% [markdown]
# # 2.Ridge Regressor

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'svd'}

# %%
# Checking R2 score for Ridge regressor
ridge=Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ridge))
print('MAE:',metrics.mean_absolute_error(y_test, pred_ridge))
print('MSE:',metrics.mean_squared_error(y_test, pred_ridge))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# R2_Score: 0.8227419617062172
# MAE: 4.38777458016588
# MSE: 25.4376226805794
# RMSE: 5.043572412544446

# %% [markdown]
# The R2 score for Ridge Regressor is 82.27%

# %% [markdown]
# # 3.Lasso Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso))
print('MAE:',metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:',metrics.mean_squared_error(y_test, pred_lasso))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597
# RMSE: 4.41299065192299

# %% [markdown]
# The R2 score for Lasso Regressor is 86.42%

# %% [markdown]
# # 4.Stochastic Gradient Descent Regressor

# %%
# Checking R2 score for Stochastic Gradient Descent Regressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

# prediction
predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# R2_Score: 0.9289818046663177
# MAE: 2.760933278931805
# MSE: 10.191549414305209
# RMSE: 3.1924206198909957

# %% [markdown]
# The R2 score using SGD is 92.89%

# %% [markdown]
# # 5. KNN Regressor

# %%
# Checking R2 score for KNN 
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# prediction
predKNN=knn.predict(x_test)
print('R2_Score:',r2_score(y_test,predKNN))
print('MAE:',metrics.mean_absolute_error(y_test, predKNN))
print('MSE:',metrics.mean_squared_error(y_test, predKNN))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predKNN)))
# Out:
# R2_Score: 0.6201479697178254
# MAE: 6.377777777777776
# MSE: 54.51111111111109
# RMSE: 7.3831640311665225

# %% [markdown]
# The R2 score using KNN is 62.01%

# %% [markdown]
# # 6 Decision Tree Regressor

# %%
# Checking R2 score for Decision tree regressor
from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# prediction
predDTR=dtr.predict(x_test)
print('R2_Score:',r2_score(y_test,predDTR))
print('MAE:',metrics.mean_absolute_error(y_test, predDTR))
print('MSE:',metrics.mean_squared_error(y_test, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predDTR)))
# Out:
# R2_Score: 0.6012560220233998
# MAE: 6.777777777777778
# MSE: 57.22222222222222
# RMSE: 7.564537145273478

# %%
The R2 score using Decision tree regressor is 60.12%

# %% [markdown]
# # Checking the cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking cv score for Linear Regression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.37344412304899344

# %%
# Checking cv score for Ridge Regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.35052495769870895

# %%
# Checking cv score for Lasso Regression
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.5206537019436117

# %%
# Checking cv score for SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.27126779317422584

# %%
# Checking cv score for KNN Regression
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.013785729869268005

# %%
# Checking cv score for SDecision tree Regression
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -2.1197266942346684

# %% [markdown]
# From the difference of both R2 score and Cross Validation score we can conclude that Lasso Rgressor as our best fitting model.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regressor
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 10,
#  'selection': 'random',
#  'tol': 1000}

# %% [markdown]
# This gives the best parameter value.

# %%
# Creating final model
BaseBall = Lasso(alpha=1.0, fit_intercept="bool", max_iter=2, selection="random", tol=100)
BaseBall.fit(x_train, y_train)
pred = BaseBall.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 86.42951302468397
# RMSE value: 4.41299065192299

# %% [markdown]
# After tunning the model R2 score for best model is 86.42%

# %% [markdown]
# # Saving the model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(BaseBall,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %%
# Let's load the saved model and get the prediction

# Loading the saved model
model=joblib.load("BaseBallCaseStudy.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([67.00222754, 81.31931881, 75.18517521, 79.68621368, 74.8424768 ,
#        70.53787164, 86.99821792, 91.6646915 , 95.75915458])

# %% [markdown]
# These are the predicted values

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  67.002228  81.319319  75.185175  79.686214  74.842477  70.537872
# Original   68.000000  78.000000  74.000000  88.000000  68.000000  64.000000
#
#                    6          7           8
# Predicted  86.998218  91.664692   95.759155
# Original   92.000000  90.000000  100.000000

# %% [markdown]
# Both original and predicted values are almost equal.

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, prediction, c='r')
plt1 = max(max(prediction), max(y_test))
plt2 = min(min(prediction), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Win', fontsize=15)
plt.ylabel('Predicted Win', fontsize=15)
plt.title("Lasso Regressor")
plt.show()

# %% [markdown]
# Plotting Actual win vs Predicted win. Here the blue line represents the actual win and red dots are the predicted win.
